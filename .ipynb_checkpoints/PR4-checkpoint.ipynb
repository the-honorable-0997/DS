# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('housing.csv')
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
x = df.drop('MEDV', axis=1)
y = df['MEDV']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(x_test)
predictions
# Out:
# array([661706.08284048, 385583.88139307, 582264.32275942, 380804.00909719,
#        558016.56496332, 525091.0030739 , 481488.37636278, 417171.01817691,
#         63947.24698614, 258975.70063418, 414961.2806172 , 471407.45147482,
#        620489.15154416, 409549.13689628, 408053.07763461, 566510.62382468,
#        456153.10422985, 407304.25704389, 601937.46525976, 380786.37412844,
#        380395.79488004, 341750.72285794, 402997.01802546, 628802.57782467,
#        519484.45047827, 433015.69955882, 724541.88985697, 616342.49079625,
#        369026.28547145, 611048.49098971, 408610.78551188, 232882.44586606,
#        369160.64847097, 243871.41342815, 456238.53155882, 620649.7131206 ,
#        457075.77023391, 364179.91827851, 446392.58670808, 501708.39033982,
#        508995.46889911, 397389.89401602, 560794.62743386, 483776.44689171,
#        564166.70956848, 325263.29595987, 625665.7388448 , 408714.57285241,
#        663769.11085984, 268394.9208758 , 504987.97173492, 388380.18438241,
#        403363.95312129, 646548.56365907, 221277.63604095, 483633.87976878,
#        523039.58343128, 550415.99206379, 457719.49926536, 510412.45345468,
#        109943.57127664, 593512.35795614, 568961.42667185, 683563.66215822,
#        364128.4886282 , 648068.62688224, 561181.72918721, 663029.57141638,
#        365155.37184061, 436785.41015463, 260481.64798963, 204035.27056213,
#        294802.46151308, 453310.8577218 , 399896.98078668, 421975.18993347,
#        513084.04937417, 486890.9964439 , 742062.10852892, 496719.89729244,
#        407336.20061483, 567150.41700858, 701857.75470147, 517158.32481982,
#        441594.51299887, 367653.00999958, 266069.43172082, 347678.28021775,
#        641743.63558211, 497473.64114296, 315758.64017145, 456677.47080884,
#        314555.74151803, 379060.60370472, 276634.40942545, 554023.24411146,
#        384190.90934102, 353309.52196413])
